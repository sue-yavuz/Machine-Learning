# %% [markdown]
# ## Adaboosting, Gradient Boosting, XGBoost Classifier

# %% [markdown]
# we will be working with a fake advertising data set, indicating whether or not a particular internet user clicked on an Advertisement on a company website. We will try to create a model that will predict whether or not they will click on an ad based off the features of that user.
#
# This data set contains the following features:
#
# * 'Daily Time Spent on Site': consumer time on site in minutes
# * 'Age': cutomer age in years
# * 'Area Income': Avg. Income of geographical area of consumer
# * 'Daily Internet Usage': Avg. minutes a day consumer is on the internet
# * 'Ad Topic Line': Headline of the advertisement
# * 'City': City of consumer
# * 'Male': Whether or not consumer was male
# * 'Country': Country of consumer
# * 'Timestamp': Time at which consumer clicked on Ad or closed window
# * 'Clicked on Ad': 0 or 1 indicated clicking on Ad

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
df = pd.read_csv('advertising2 .csv')
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# 1  2016-04-04 01:39:02              0
# 2  2016-03-13 20:35:42              0
# 3  2016-01-10 02:31:19              0
# 4  2016-06-03 03:36:18              0

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
df.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# 75%              218.792500     1.000000        1.00000
# max              269.960000     1.000000        1.00000

# %%
sns.pairplot(df, hue='Clicked on Ad')

# %% [markdown]
# ## Train | Test Split

# %%
for feature in df.columns:
    if df[feature].dtype=="object":
        print(feature, df[feature].nunique())
# Out:
# Ad Topic Line 1000
# City 969
# Country 237
# Timestamp 1000

# %%
from sklearn.model_selection import train_test_split

# %%
cat = df.select_dtypes("object").columns
cat
# Out:
# Index(['Ad Topic Line', 'City', 'Country', 'Timestamp'], dtype='object')

# %%
list(cat)
# Out:
# ['Ad Topic Line', 'City', 'Country', 'Timestamp']

# %%
cat2 = list(cat) + ['Clicked on Ad']
cat2
# Out:
# ['Ad Topic Line', 'City', 'Country', 'Timestamp', 'Clicked on Ad']

# %%
X = df.drop(columns=cat2)
y = df['Clicked on Ad']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
X_train.head(1)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 716                     39.96   35     53898.89                138.52     1

# %% [markdown]
# ## Modelling and Model Performance

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from sklearn.model_selection import cross_val_score, cross_validate

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
#base_estimator=DecisionTreeClassifier(max_depth=1)
ada_model = AdaBoostClassifier(n_estimators=50, random_state=42)

# %%
ada_model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(random_state=42)

# %%
eval_metric(ada_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[41  3]
#  [ 4 52]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92        44
#            1       0.95      0.93      0.94        56
#
#     accuracy                           0.93       100
#    macro avg       0.93      0.93      0.93       100
# weighted avg       0.93      0.93      0.93       100
#
#
# Train_Set
# [[454   2]
#  [ 12 432]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       456
#            1       1.00      0.97      0.98       444
#
#     accuracy                           0.98       900
#    macro avg       0.98      0.98      0.98       900
# weighted avg       0.98      0.98      0.98       900

# %%
from sklearn.model_selection import cross_val_score, cross_validate

model = AdaBoostClassifier(n_estimators=50, random_state=42)

scores = cross_validate(model, X_train, y_train, scoring = ["accuracy", "precision", "recall", "f1"], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy     0.960000
# test_precision    0.968795
# test_recall       0.950505
# test_f1           0.958988
# dtype: float64

# %% [markdown]
# ## Tree Visualization

# %%
from sklearn.tree import plot_tree

# %%
model = AdaBoostClassifier(n_estimators=3, random_state=42)
model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=3, random_state=42)

# %%
targets = df["Clicked on Ad"].astype("str")
plt.figure(figsize=(12,8),dpi=150)
plot_tree(model.estimators_[2], filled=True, feature_names=X.columns, class_names=targets.unique());

# %% [markdown]
# ## Gridsearch

# %%
from sklearn.model_selection import GridSearchCV

# %%
model = AdaBoostClassifier(random_state=42)

# %%
param_grid = {"n_estimators": [20, 30, 100, 200], "learning_rate": [0.01, 0.1, 0.2, 0.5, 1.0]}

# %%
ada_grid_model = GridSearchCV(model, param_grid, cv=5, scoring= 'f1')

# %%
ada_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(random_state=42),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2, 0.5, 1.0],
#                          'n_estimators': [20, 30, 100, 200]},
#              scoring='f1')

# %%
ada_grid_model.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}

# %%
ada_grid_model.best_score_
# Out:
# 0.969132103588408

# %%
y_pred = ada_grid_model.predict(X_test)
y_pred_proba = ada_grid_model.predict_proba(X_test)

ada_f1 = f1_score(y_test, y_pred)
ada_recall = recall_score(y_test, y_pred)
ada_auc = roc_auc_score(y_test, y_pred_proba[:,1])
eval_metric(ada_grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[40  4]
#  [ 3 53]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92        44
#            1       0.93      0.95      0.94        56
#
#     accuracy                           0.93       100
#    macro avg       0.93      0.93      0.93       100
# weighted avg       0.93      0.93      0.93       100
#
#
# Train_Set
# [[453   3]
#  [ 18 426]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       456
#            1       0.99      0.96      0.98       444
#
#     accuracy                           0.98       900
#    macro avg       0.98      0.98      0.98       900
# weighted avg       0.98      0.98      0.98       900

# %% [markdown]
# ## Feature_importances

# %%
model = AdaBoostClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
model.fit(X_train, y_train)
model.feature_importances_

feats = pd.DataFrame(index=X.columns, data= model.feature_importances_, columns=['ada_importance'])
ada_imp_feats = feats.sort_values("ada_importance", ascending = False)
ada_imp_feats
# Out:
#                           ada_importance
# Daily Internet Usage                0.29
# Daily Time Spent on Site            0.28
# Age                                 0.22
# Area Income                         0.21
# Male                                0.00

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(data=ada_imp_feats ,x=ada_imp_feats.index, y='ada_importance')
ax.bar_label(ax.containers[0],fmt="%.3f");
plt.xticks(rotation=90);

# %% [markdown]
# ## Evaluating ROC Curves and AUC

# %%
from sklearn.metrics import precision_recall_curve, plot_precision_recall_curve, plot_roc_curve, roc_auc_score

# %%
plot_roc_curve(ada_grid_model, X_test, y_test)

# %% [markdown]
# ## Gradient Boosting Modelling and Model Performance

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
grad_model = GradientBoostingClassifier(random_state=42)

# %%
grad_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
eval_metric(grad_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[41  3]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        44
#            1       0.95      0.96      0.96        56
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
#
# Train_Set
# [[456   0]
#  [  1 443]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       456
#            1       1.00      1.00      1.00       444
#
#     accuracy                           1.00       900
#    macro avg       1.00      1.00      1.00       900
# weighted avg       1.00      1.00      1.00       900

# %%
model = GradientBoostingClassifier(random_state=42)

scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision','recall',
                                                            'f1', 'roc_auc'], cv = 10,)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy     0.952222
# test_precision    0.958870
# test_recall       0.945960
# test_f1           0.951603
# test_roc_auc      0.987972
# dtype: float64

# %% [markdown]
# ## Gridsearch

# %%
param_grid = {"n_estimators":[100, 200, 300], "subsample":[0.5, 1], "max_features" : [None, 2, 3, 4], 
              "learning_rate": [0.001, 0.01, 0.1], 'max_depth':[3,4,5,6]} #0.8

# %%
gb_model = GradientBoostingClassifier(random_state = 42)

# %%
grid = GridSearchCV(gb_model, param_grid, scoring = "f1", verbose=2, n_jobs = -1).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=0.5; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=300, subsample=0.5; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=300, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=300, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=300, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=300, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=300, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=300, subsample=1; total time=   2.9s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=300, subsample=1; total time=   2.8s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=300, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=None, n_estimators=300, subsample=1; total time=   2.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=0.5; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=300, subsample=0.5; total time=   2.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=300, subsample=0.5; total time=   2.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=300, subsample=0.5; total time=   3.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=300, subsample=0.5; total time=   3.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=300, subsample=0.5; total time=   2.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=300, subsample=1; total time=   3.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=300, subsample=1; total time=   2.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=300, subsample=1; total time=   2.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=300, subsample=1; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=3, max_features=2, n_estimators=300, subsample=1; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=200, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=300, subsample=0.5; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=300, subsample=0.5; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=300, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=300, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=300, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=300, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=300, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=300, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=300, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=3, n_estimators=300, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=200, subsample=0.5; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=200, subsample=0.5; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=200, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=200, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=200, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=200, subsample=1; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=200, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=200, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=300, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=300, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=300, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=300, subsample=0.5; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=300, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=300, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=300, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=300, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=300, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=3, max_features=4, n_estimators=300, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=200, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=300, subsample=0.5; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=300, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=300, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=300, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=300, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=300, subsample=1; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=300, subsample=1; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=300, subsample=1; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=300, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=None, n_estimators=300, subsample=1; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=100, subsample=1; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=300, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=300, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=300, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=300, subsample=0.5; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=300, subsample=0.5; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=300, subsample=1; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=300, subsample=1; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=300, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=300, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=2, n_estimators=300, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=200, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=300, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=300, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=300, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=300, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=300, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=300, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=300, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=300, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=300, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=3, n_estimators=300, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=300, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=300, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=300, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=300, subsample=0.5; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=300, subsample=0.5; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=300, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=300, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=300, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=300, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=4, max_features=4, n_estimators=300, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=200, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=300, subsample=0.5; total time=   1.9s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=300, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=300, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=300, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=300, subsample=0.5; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=300, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=300, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=300, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=300, subsample=1; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=None, n_estimators=300, subsample=1; total time=   1.9s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=200, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=300, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=300, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=300, subsample=0.5; total time=   2.9s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=300, subsample=0.5; total time=   2.9s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=300, subsample=0.5; total time=   3.0s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=300, subsample=1; total time=   3.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=300, subsample=1; total time=   2.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=300, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=300, subsample=1; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=2, n_estimators=300, subsample=1; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=200, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=300, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=300, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=300, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=300, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=300, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=300, subsample=1; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=300, subsample=1; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=300, subsample=1; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=100, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=300, subsample=1; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=3, n_estimators=300, subsample=1; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=200, subsample=0.5; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=200, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=200, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=200, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=200, subsample=1; total time=   1.2s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=200, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=300, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=300, subsample=0.5; total time=   1.9s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=300, subsample=0.5; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=300, subsample=0.5; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=300, subsample=0.5; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=300, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=300, subsample=1; total time=   1.9s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=300, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=100, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=300, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=5, max_features=4, n_estimators=300, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=200, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=200, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=200, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=200, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=200, subsample=1; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=200, subsample=0.5; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=200, subsample=1; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=200, subsample=1; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=200, subsample=1; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=200, subsample=1; total time=   1.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=300, subsample=0.5; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=300, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=300, subsample=0.5; total time=   2.2s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=300, subsample=0.5; total time=   2.3s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=300, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=300, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=300, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=300, subsample=1; total time=   1.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=300, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=100, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=100, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=6, max_features=None, n_estimators=300, subsample=1; total time=   2.4s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=100, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=100, subsample=0.5; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=100, subsample=0.5; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=100, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=100, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=100, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=100, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=100, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=200, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=200, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=200, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=200, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=200, subsample=0.5; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=200, subsample=1; total time=   1.6s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=200, subsample=1; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=200, subsample=1; total time=   1.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=200, subsample=1; total time=   2.0s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=200, subsample=1; total time=   1.8s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=300, subsample=0.5; total time=   2.4s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=300, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=300, subsample=0.5; total time=   2.6s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=300, subsample=0.5; total time=   2.8s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=300, subsample=0.5; total time=   2.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=300, subsample=1; total time=   2.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=300, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=300, subsample=1; total time=   2.6s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=300, subsample=1; total time=   2.6s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.001, max_depth=6, max_features=2, n_estimators=300, subsample=1; total time=   2.8s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=100, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=100, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=100, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=100, subsample=1; total time=   0.8s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=100, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=100, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=100, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=100, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=200, subsample=0.5; total time=   1.4s
# [CV] END learning_rate=0.001, max_depth=6, max_features=3, n_estimators=200, subsample=0.5; total time=   1.4s
# ...
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=100, subsample=0.5; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=100, subsample=0.5; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=100, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=100, subsample=1; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=100, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=100, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=100, subsample=1; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=200, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=200, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=200, subsample=0.5; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=200, subsample=0.5; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=200, subsample=0.5; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=200, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=200, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=200, subsample=1; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=200, subsample=1; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=200, subsample=1; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=300, subsample=0.5; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=300, subsample=0.5; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=300, subsample=0.5; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=300, subsample=0.5; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=300, subsample=0.5; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=300, subsample=1; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=300, subsample=1; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=300, subsample=1; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=100, subsample=0.5; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=300, subsample=1; total time=   4.0s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=5, max_features=4, n_estimators=300, subsample=1; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=100, subsample=0.5; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=100, subsample=0.5; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=100, subsample=1; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=100, subsample=1; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=100, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=100, subsample=1; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=100, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=200, subsample=0.5; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=200, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=200, subsample=0.5; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=200, subsample=0.5; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=200, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=200, subsample=1; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=200, subsample=1; total time=   3.0s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=200, subsample=1; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=200, subsample=1; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=200, subsample=1; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=300, subsample=0.5; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=300, subsample=0.5; total time=   4.6s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=300, subsample=0.5; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=300, subsample=0.5; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=300, subsample=0.5; total time=   2.9s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=300, subsample=1; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=300, subsample=1; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=300, subsample=1; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=300, subsample=1; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=100, subsample=0.5; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=None, n_estimators=300, subsample=1; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=100, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=100, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=100, subsample=1; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=100, subsample=1; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=100, subsample=1; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=100, subsample=1; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=200, subsample=0.5; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=200, subsample=0.5; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=200, subsample=0.5; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=200, subsample=0.5; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=200, subsample=0.5; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=200, subsample=1; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=200, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=200, subsample=1; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=200, subsample=1; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=200, subsample=1; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=300, subsample=0.5; total time=   5.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=300, subsample=0.5; total time=   5.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=300, subsample=0.5; total time=   7.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=300, subsample=0.5; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=300, subsample=0.5; total time=  10.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=300, subsample=1; total time=  11.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=300, subsample=1; total time=  15.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=300, subsample=1; total time=  15.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=100, subsample=0.5; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=300, subsample=1; total time=  16.0s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=100, subsample=0.5; total time=   3.9s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=100, subsample=0.5; total time=   3.6s
# [CV] END learning_rate=0.1, max_depth=6, max_features=2, n_estimators=300, subsample=1; total time=  16.6s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=100, subsample=0.5; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=100, subsample=0.5; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=100, subsample=1; total time=   5.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=100, subsample=1; total time=   5.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=100, subsample=1; total time=   5.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=100, subsample=1; total time=   4.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=100, subsample=1; total time=   5.9s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=200, subsample=0.5; total time=   9.6s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=200, subsample=0.5; total time=   8.9s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=200, subsample=0.5; total time=   8.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=200, subsample=0.5; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=200, subsample=0.5; total time=   3.6s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=200, subsample=1; total time=   5.6s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=200, subsample=1; total time=   5.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=200, subsample=1; total time=   6.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=200, subsample=1; total time=   5.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=200, subsample=1; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=300, subsample=0.5; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=300, subsample=0.5; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=300, subsample=0.5; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=300, subsample=0.5; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=300, subsample=0.5; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=300, subsample=1; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=300, subsample=1; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=300, subsample=1; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=100, subsample=0.5; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=300, subsample=1; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=100, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=100, subsample=0.5; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=100, subsample=0.5; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=3, n_estimators=300, subsample=1; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=100, subsample=0.5; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=100, subsample=1; total time=   3.0s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=100, subsample=1; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=100, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=100, subsample=1; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=100, subsample=1; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=200, subsample=0.5; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=200, subsample=0.5; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=200, subsample=0.5; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=200, subsample=0.5; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=200, subsample=0.5; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=200, subsample=1; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=200, subsample=1; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=200, subsample=1; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=200, subsample=1; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=200, subsample=1; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=300, subsample=0.5; total time=   6.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=300, subsample=0.5; total time=   6.9s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=300, subsample=0.5; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=300, subsample=0.5; total time=   4.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=300, subsample=0.5; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=300, subsample=1; total time=   5.8s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=300, subsample=1; total time=   6.0s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=300, subsample=1; total time=   5.7s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=300, subsample=1; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=6, max_features=4, n_estimators=300, subsample=1; total time=   5.5s

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 3,
#  'max_features': 3,
#  'n_estimators': 100,
#  'subsample': 0.5}

# %%
grid.best_estimator_
# Out:
# GradientBoostingClassifier(max_features=3, random_state=42, subsample=0.5)

# %%
grid.best_score_
# Out:
# 0.9658340599400116

# %%
y_pred = grid.predict(X_test)
y_pred_proba = grid.predict_proba(X_test)

gb_f1 = f1_score(y_test, y_pred)
gb_recall = recall_score(y_test, y_pred)
gb_auc = roc_auc_score(y_test, y_pred_proba[:,1])

eval_metric(grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[42  2]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        44
#            1       0.96      0.96      0.96        56
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100
#
#
# Train_Set
# [[456   0]
#  [  4 440]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       456
#            1       1.00      0.99      1.00       444
#
#     accuracy                           1.00       900
#    macro avg       1.00      1.00      1.00       900
# weighted avg       1.00      1.00      1.00       900

# %% [markdown]
# ## Feature importances

# %%
model = GradientBoostingClassifier(max_features= 3, n_estimators = 100, subsample = 0.5, random_state=42)
model.fit(X_train, y_train)

model.feature_importances_

feats = pd.DataFrame(index=X.columns, data=model.feature_importances_, columns=['grad_importance'])
grad_imp_feats = feats.sort_values("grad_importance", ascending=False)
grad_imp_feats
# Out:
#                           grad_importance
# Daily Internet Usage             0.551346
# Daily Time Spent on Site         0.319058
# Area Income                      0.074586
# Age                              0.053003
# Male                             0.002008

# %%
plt.figure(figsize=(12,6))
ax = sns.barplot(data=grad_imp_feats, x=grad_imp_feats.index, y='grad_importance')
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.xticks(rotation=90);

# %% [markdown]
# ## Evaluating ROC Curves and AUC

# %%
plot_roc_curve(grid, X_test, y_test);

# %% [markdown]
# ## XG Boosting Modelling and Model Performance

# %%
# pip install xgboost==0.90

# %%
import xgboost as xgb

xgb.__version__
# Out:
# '0.90'

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(random_state=42).fit(X_train, y_train)

# %%
eval_metric(xgb, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[40  4]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        44
#            1       0.93      0.96      0.95        56
#
#     accuracy                           0.94       100
#    macro avg       0.94      0.94      0.94       100
# weighted avg       0.94      0.94      0.94       100
#
#
# Train_Set
# [[454   2]
#  [  7 437]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       456
#            1       1.00      0.98      0.99       444
#
#     accuracy                           0.99       900
#    macro avg       0.99      0.99      0.99       900
# weighted avg       0.99      0.99      0.99       900

# %%
model = XGBClassifier(random_state=42)

scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision','recall',
                                                                   'f1', 'roc_auc'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy     0.957778
# test_precision    0.968757
# test_recall       0.945909
# test_f1           0.956573
# test_roc_auc      0.988441
# dtype: float64

# %% [markdown]
# ## Gridsearch

# %%
param_grid = {"n_estimators":[50, 100, 200],'max_depth':[3,4,5], "learning_rate": [0.1, 0.2],
             "subsample":[0.5, 0.8, 1], "colsample_bytree":[0.5,0.7, 1]}

# %%
xgb_model = XGBClassifier(random_state=42)

# %%
xgb_grid = GridSearchCV(xgb_model, param_grid, scoring = "f1", verbose=2, n_jobs = -1).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s[CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
#
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1; total time=   1.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1; total time=   1.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.5s[CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.5s
#
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=1; total time=   1.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=1; total time=   1.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1; total time=   0.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1; total time=   0.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1; total time=   1.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.5; total time=   1.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.5; total time=   1.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1; total time=   1.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1; total time=   1.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   1.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   1.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   1.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.5; total time=   1.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1; total time=   0.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=50, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=1; total time=   0.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.5; total time=   1.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=4, n_estimators=200, subsample=1; total time=   0.5s[CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.2s
#
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1; total time=   0.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# ...
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.2s[CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.1s
#
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1; total time=   0.8s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s[CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
#
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=4, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.5; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=50, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=1; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.5; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1; total time=   0.3s

# %%
xgb_grid.best_params_
# Out:
# {'colsample_bytree': 0.5,
#  'learning_rate': 0.1,
#  'max_depth': 3,
#  'n_estimators': 100,
#  'subsample': 1}

# %%
xgb_grid.best_estimator_
# Out:
# XGBClassifier(colsample_bytree=0.5, random_state=42)

# %%
xgb_grid.best_score_
# Out:
# 0.969269374396047

# %%
y_pred = xgb_grid.predict(X_test)
y_pred_proba = xgb_grid.predict_proba(X_test)

xgb_f1 = f1_score(y_test, y_pred)
xgb_recall = recall_score(y_test, y_pred)
xgb_auc = roc_auc_score(y_test, y_pred_proba[:,1])

eval_metric(xgb_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[40  4]
#  [ 4 52]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        44
#            1       0.93      0.93      0.93        56
#
#     accuracy                           0.92       100
#    macro avg       0.92      0.92      0.92       100
# weighted avg       0.92      0.92      0.92       100
#
#
# Train_Set
# [[454   2]
#  [ 13 431]]
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       456
#            1       1.00      0.97      0.98       444
#
#     accuracy                           0.98       900
#    macro avg       0.98      0.98      0.98       900
# weighted avg       0.98      0.98      0.98       900

# %% [markdown]
# ## Feature importances

# %%
model = XGBClassifier(random_state=42, colsample_bytree = 0.5, subsample= 0.8)
model.fit(X_train, y_train)

model.feature_importances_

feats = pd.DataFrame(index=X.columns, data=model.feature_importances_, columns=['xgb_importance'])
xgb_imp_feats = feats.sort_values("xgb_importance", ascending=False)
xgb_imp_feats
# Out:
#                           xgb_importance
# Daily Internet Usage            0.467174
# Daily Time Spent on Site        0.301327
# Age                             0.122702
# Area Income                     0.087656
# Male                            0.021141

# %%
ax = sns.barplot(data=xgb_imp_feats, x=xgb_imp_feats.index,y='xgb_importance')
ax.bar_label(ax.containers[0],fmt="%.3f")
plt.xticks(rotation=90);

# %% [markdown]
# ## Feature importance comparison

# %%
pd.concat([ada_imp_feats, grad_imp_feats, xgb_imp_feats], axis=1)
# Out:
#                           ada_importance  grad_importance  xgb_importance
# Daily Internet Usage                0.29         0.551346        0.467174
# Daily Time Spent on Site            0.28         0.319058        0.301327
# Age                                 0.22         0.053003        0.122702
# Area Income                         0.21         0.074586        0.087656
# Male                                0.00         0.002008        0.021141

# %% [markdown]
# ## Evaluating ROC Curves and AUC

# %%
plot_roc_curve(xgb_grid, X_test, y_test);

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train,y_train)

y_pred = rf_model.predict(X_test)
y_pred_proba = rf_model.predict_proba(X_test)

rf_f1 = f1_score(y_test, y_pred)
rf_recall = recall_score(y_test, y_pred)
rf_auc = roc_auc_score(y_test, y_pred_proba[:,1])
eval_metric(rf_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[41  3]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        44
#            1       0.95      0.96      0.96        56
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
#
# Train_Set
# [[456   0]
#  [  0 444]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       456
#            1       1.00      1.00      1.00       444
#
#     accuracy                           1.00       900
#    macro avg       1.00      1.00      1.00       900
# weighted avg       1.00      1.00      1.00       900

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)

y_pred = dt_model.predict(X_test)
y_pred_proba = dt_model.predict_proba(X_test)

dt_f1 = f1_score(y_test, y_pred)
dt_recall = recall_score(y_test, y_pred)
dt_auc = roc_auc_score(y_test, y_pred_proba[:,1])

eval_metric(dt_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[38  6]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90        44
#            1       0.90      0.96      0.93        56
#
#     accuracy                           0.92       100
#    macro avg       0.93      0.91      0.92       100
# weighted avg       0.92      0.92      0.92       100
#
#
# Train_Set
# [[456   0]
#  [  0 444]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       456
#            1       1.00      1.00      1.00       444
#
#     accuracy                           1.00       900
#    macro avg       1.00      1.00      1.00       900
# weighted avg       1.00      1.00      1.00       900

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression

# %%
scaler = MinMaxScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
log_model=LogisticRegression()
log_model.fit(X_train_scaled, y_train)

y_pred=log_model.predict(X_test_scaled)
y_pred_proba = log_model.predict_proba(X_test_scaled)

log_f1 = f1_score(y_test, y_pred)
log_recall = recall_score(y_test, y_pred)
log_auc = roc_auc_score(y_test, y_pred_proba[:,1])
eval_metric(log_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Test_Set
# [[43  1]
#  [ 3 53]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96        44
#            1       0.98      0.95      0.96        56
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100
#
#
# Train_Set
# [[451   5]
#  [ 22 422]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       456
#            1       0.99      0.95      0.97       444
#
#     accuracy                           0.97       900
#    macro avg       0.97      0.97      0.97       900
# weighted avg       0.97      0.97      0.97       900

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(X_train_scaled, y_train)

y_pred = knn_model.predict(X_test_scaled)
y_pred_proba = knn_model.predict_proba(X_test_scaled)

knn_f1 = f1_score(y_test, y_pred)
knn_recall = recall_score(y_test, y_pred)
knn_auc = roc_auc_score(y_test, y_pred_proba[:,1])

eval_metric(knn_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Test_Set
# [[42  2]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        44
#            1       0.96      0.96      0.96        56
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100
#
#
# Train_Set
# [[454   2]
#  [ 24 420]]
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       456
#            1       1.00      0.95      0.97       444
#
#     accuracy                           0.97       900
#    macro avg       0.97      0.97      0.97       900
# weighted avg       0.97      0.97      0.97       900

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC(probability=True)
svm_model.fit(X_train_scaled, y_train)

y_pred = svm_model.predict(X_test_scaled)
y_pred_proba = svm_model.predict_proba(X_test_scaled)

svc_f1 = f1_score(y_test, y_pred)
svc_recall = recall_score(y_test, y_pred)
svc_auc = roc_auc_score(y_test, y_pred_proba[:,1])

eval_metric(svm_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Test_Set
# [[42  2]
#  [ 2 54]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        44
#            1       0.96      0.96      0.96        56
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100
#
#
# Train_Set
# [[450   6]
#  [ 17 427]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       456
#            1       0.99      0.96      0.97       444
#
#     accuracy                           0.97       900
#    macro avg       0.97      0.97      0.97       900
# weighted avg       0.97      0.97      0.97       900

# %% [markdown]
# ## Comparing Models

# %%
compare = pd.DataFrame({"Model": ["Logistic Regression", "KNN", "SVM", "Decision Tree", "Random Forest", "AdaBoost",
                                 "GradientBoost", "XGBoost"],
                        "F1": [log_f1, knn_f1, svc_f1, dt_f1, rf_f1, ada_f1, gb_f1, xgb_f1],
                        "Recall": [log_recall, knn_recall, svc_recall, dt_recall, rf_recall, ada_recall, gb_recall, 
                                   xgb_recall],
                        "ROC_AUC": [log_auc, knn_auc, svc_auc, dt_auc, rf_auc, ada_auc, gb_auc, xgb_auc]})

def labels(ax):
    ax.bar_label(ax.containers[0],fmt="%.3f")
    
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="ROC_AUC", ascending=False)
ax=sns.barplot(x="ROC_AUC", y="Model", data=compare, palette="Blues_d")
labels(ax)
plt.show()
